# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
img = Image.open('data/dog.jpg')

# %%
plt.imshow(img)

# %%
np_img = np.array(img)

# %%
np_img_norm = np_img /255

# %%
plt.imshow(np_img_norm)
